# %% [raw]
# Reference: [Yoked Learning in Molecular Data Science](https://chemrxiv.org/engage/chemrxiv/article-details/64d977544a3f7d0c0d1fedcb)
# In contrast to traditional active learning, which employs the same model for both data selection and performance evaluation, yoked learning represents a similar learning approach. In yoked learning, a 'teacher' model is used to select the data, while a separate 'student' model is employed to evaluate performance."

# %%
# Here is an example that use random forest as teacher model and logistic regression as student model
# !molalkit_run --data_public bace --metrics roc-auc --learning_type explorative --model_config_selector RandomForest_RDKitNorm_Config --split_type scaffold_order --split_sizes 0.5 0.5 --evaluate_stride 10 --seed 0 --save_dir bace_rf_yoked_lr --n_jobs 4 --model_config_evaluators LogisticRegression_RDkitNorm_Config
# Out:
# 100%|█████████████████████████████████████| 1513/1513 [00:00<00:00, 2354.72it/s]
# Total scaffolds = 671 |
# split 0 scaffolds = 75 |
# split 1 scaffolds = 596 |
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 668 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=4)]: Done 748 out of 755 | elapsed:   11.0s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 755 out of 755 | elapsed:   11.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=4)]: Done 756 out of 756 | elapsed:   10.0s finished
# Start a new active learning run.
# ...

# %%
# Here's an example where a random forest serves as the teacher model, while the D-MPNN-RDKit is used as the student model. This scenario employs a deep learning model as the student model, leading to what is known as 'deep yoked learning' (DeYoL).
# !molalkit_run --data_public bace --metrics roc-auc --learning_type explorative --model_config_selector RandomForest_RDKitNorm_Config --split_type scaffold_order --split_sizes 0.5 0.5 --evaluate_stride 100 --seed 0 --save_dir bace_rf_yoked_dmpnn --n_jobs 4 --model_config_evaluators DMPNN+RDKitNorm_BinaryClassification_Config
# Out:
# 100%|█████████████████████████████████████| 1513/1513 [00:00<00:00, 2430.73it/s]
# Total scaffolds = 671 |
# split 0 scaffolds = 75 |
# split 1 scaffolds = 596 |
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 668 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=4)]: Done 748 out of 755 | elapsed:   11.3s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done 755 out of 755 | elapsed:   11.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 728 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=4)]: Done 756 out of 756 | elapsed:    9.9s finished
# Start a new active learning run.
# ...
